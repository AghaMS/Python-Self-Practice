# %%
# importing libraries

# to iterate through directories
import os

# to do some image operations
import cv2

# to plot images 
import matplotlib.pyplot as plt

import random
import math
import numpy as np
import tensorflow as tf
from tensorflow.python.framework import ops

# %matplotlib inline
np.random.seed(3)

# %%
# Define our working directory
DATA_DIR = os.getcwd()#"./pictures"
print(DATA_DIR)

# Define our classes
CLASSES = ["M", "NM"]
# Out:
# /Users/mohammedagha/Desktop/Python sandbox/pictures

# %%
# Check for any .DS files
for label in CLASSES:
    print(label)
    # path to Mohammed or notMohammed
    path = os.path.join(DATA_DIR, label)
    print(path)
    for img in os.listdir(path):
        print(img, ""); print(os.path.join(path, img))
    print()
# Out:
# M
# /Users/mohammedagha/Desktop/Python sandbox/pictures/M
# DSCF1689.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/M/DSCF1689.JPG
# DSCF1694.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/M/DSCF1694.JPG
# DSCF1695.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/M/DSCF1695.JPG
# DSCF1687.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/M/DSCF1687.JPG
#
# NM
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM
# DSCF1672.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1672.JPG
# DSCF1706.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1706.JPG
# DSCF1610.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1610.JPG
# DSCF1801.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1801.JPG
# DSCF1633.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1633.JPG
# DSCF1708.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1708.JPG
# DSCF1692.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1692.JPG
# DSCF1686.JPG
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM/DSCF1686.JPG

# %%
for label in CLASSES:
    # path to Mohammed or notMohammed
    path = os.path.join(DATA_DIR, label); print(path)
    
    for img in os.listdir(path):
        #img_array = cv2.resize(cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE),(96,96))
        #plt.imshow(img_array, cmap = "gray")
        img_array = cv2.resize(cv2.imread(os.path.join(path, img)),(96,96))
        plt.imshow(img_array, cmap = "gray")
        plt.show()
        print(img_array.shape)
# Out:
# /Users/mohammedagha/Desktop/Python sandbox/pictures/M
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)
# /Users/mohammedagha/Desktop/Python sandbox/pictures/NM
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)
# (96, 96, 3)

# %%
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-9d1258567132> in <module>
# ----> 1 train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()
#
# NameError: name 'load_dataset' is not defined

# %%
train_set_x_orig = []

def create_training_data():
    for label in CLASSES:
        path = os.path.join(DATA_DIR, label)
        
        Class_num = CLASSES.index(label)
        
        for img in os.listdir(path):
            try:
                img_array = cv2.resize(cv2.imread(os.path.join(path, img)),(96,96))
                train_set_x_orig.append([img_array, Class_num])
            except Exception as e:
                pass

# %%
create_training_data()

# %% [markdown]
# Before we proceed, we need to shuffle our training data

# %%
random.shuffle(train_set_x_orig)

# %% [markdown]
# Up to this point, our training set is of type list, to be able to process it, we need it to be of type np.array

# %% [markdown]
# We will create two lists, X and Y. X will contain the features while Y will contain the label of the respective image.

# %%
X = []
Y = []

for feature, label in train_set_x_orig:
    X.append(feature)
    Y.append(label)

# %%
X = np.array(X).reshape(-1, 96,96,3)
Y = np.array(Y)
print(X.shape)
# Out:
# (12, 96, 96, 3)

# %%
#for sample in train_set_x_orig:
 #   print(sample[1])

print(Y)
# Out:
# [1 1 0 1 0 1 1 1 1 0 0 1]

# %%
X = []
Y = []
